# %%
import pandas as pd
import numpy as np
import talib as ta
###读入每日指数数据
BM_price=pd.read_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\code\\h30255CSI_daily.csv',sep=',')
BM_weight=pd.read_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\code\\h30255CSI.csv',sep=',')

##读入指数成分股每日指标数据
stocks_index_d=pd.read_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\code\\index_daily.csv',sep=',')
stocks_price_d=pd.read_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\code\\stocks_daily.csv',sep=',')

# %%
##mometum factor
#stocks_price_d['H/L']=np.zeros(len(stocks_index_d.index))
#for i in range(len(stocks_price_d.index)):
#    stocks_price_d['H/L'].iloc[i]=np.log(
#        np.max(stocks_price_d['high'].iloc[i:i+9])/np.min(stocks_price_d['low'].iloc[i:i+9]))

# %%
stocks_price_d=stocks_price_d.iloc[::-1]
stocks_index_d=stocks_index_d.iloc[::-1]

##caculate alpha mometum factors
stocks_price_d['MOM']=ta.MOM(stocks_price_d['close'],10)
stocks_price_d['APO']=ta.APO(stocks_price_d['close'],10,20,0)
stocks_price_d['ROC']=ta.ROC(stocks_price_d['close'],10)
stocks_price_d['RSI']=ta.RSI(stocks_price_d['close'],10)
stocks_price_d['vol_volatility_1w']=ta.STDDEV(stocks_price_d['vol'],5)
stocks_price_d['vol_volatility_2w']=ta.STDDEV(stocks_price_d['vol'],10)
stocks_price_d['vol_volatility_1m']=ta.STDDEV(stocks_price_d['vol'],20)
##caculate alpha volume factors
stocks_price_d['OBV']=ta.OBV(stocks_price_d['close'],stocks_price_d['vol'])
##caculate alpha volatility factors
stocks_price_d['volatility_1w']=ta.STDDEV(stocks_price_d['pct_chg'],5)
stocks_price_d['volatility_2w']=ta.STDDEV(stocks_price_d['pct_chg'],10)
stocks_price_d['volatility_1m']=ta.STDDEV(stocks_price_d['pct_chg'],20)

stocks_price_d=stocks_price_d.iloc[::-1]
stocks_index_d=stocks_index_d.iloc[::-1]

# %%
###set the trade_date as datetime index
BM_price['trade_date']=pd.to_datetime(BM_price['trade_date'],format='%Y%m%d')
BM_price=BM_price.set_index('trade_date')

BM_weight['trade_date']=pd.to_datetime(BM_weight['trade_date'],format='%Y%m%d')
BM_weight=BM_weight.set_index('trade_date')

stocks_index_d['trade_date']=pd.to_datetime(stocks_index_d['trade_date'],format='%Y%m%d')
stocks_index_d=stocks_index_d.set_index('trade_date')

stocks_price_d['trade_date']=pd.to_datetime(stocks_price_d['trade_date'],format='%Y%m%d')
stocks_price_d=stocks_price_d.set_index('trade_date')

# %%
#Due to the available datas in BM_price has NaN from 2019-06-12 to 2019-07-01
##we update all the available datas ending up on 2019-05-31 
BM_price_real=BM_price[BM_price.index<=pd.datetime(2019,5,31)]
BM_weight_real=BM_weight[BM_weight.index<=pd.datetime(2019,5,31)]
stocks_index_d_real=stocks_index_d[stocks_index_d.index<=pd.datetime(2019,5,31)]
stocks_price_d_real=stocks_price_d[stocks_price_d.index<=pd.datetime(2019,5,31)]

# %%
stocks_price_d_real.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\stocks_price_d_real.csv', 
                        sep=',', header=True, index=True)

# %%
stocks_index_d_real.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\stocks_index_d_real.csv', 
                        sep=',', header=True, index=True)

# %%
BM_price_real.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\BM_price_real.csv', 
                        sep=',', header=True, index=True)

# %%
BM_weight_real.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\BM_weight_real.csv', 
                        sep=',', header=True, index=True)

# %%
Data_for_alphlen=pd.concat([stocks_price_d_real,stocks_index_d_real],
                           axis=1)
Data_for_alphlen=Data_for_alphlen.drop('ts_code',axis=1)
Data_for_alphlen=pd.concat([stocks_index_d_real['ts_code'],Data_for_alphlen],
                           axis=1)

# %%
Data_for_alphlen.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\Data_for_alphlen.csv', 
                        sep=',', header=True, index=True)

# %%
#define tradedate respectively per month and per day
tradedate_m=BM_weight_real.index
tradedate_d=BM_price_real.index
tradedate_m=tradedate_m.drop_duplicates()
tradedate_m
# Out:
# DatetimeIndex(['2019-05-31', '2019-04-30', '2019-03-29', '2019-02-28',
#                '2019-01-31', '2018-12-28', '2018-10-31', '2018-09-28',
#                '2018-08-31', '2018-07-31', '2018-06-29', '2018-05-31',
#                '2018-04-27', '2018-03-30', '2018-02-28', '2018-01-31',
#                '2017-12-29', '2017-11-30', '2017-10-31', '2017-09-29',
#                '2017-08-31', '2017-07-31', '2017-06-30', '2017-05-31',
#                '2017-04-28', '2017-03-31', '2017-02-28', '2017-01-26',
#                '2016-12-30', '2016-11-30', '2016-10-31', '2016-09-30',
#                '2016-08-31', '2016-07-29', '2016-06-30', '2016-05-31',
#                '2016-04-29', '2016-03-31', '2016-02-29', '2016-01-29',
#                '2015-12-31', '2015-11-30', '2015-10-30', '2015-09-30',
#                '2015-08-31', '2015-07-31', '2015-06-30', '2015-05-29',
#                '2015-04-30', '2015-03-31', '2015-02-27', '2015-01-30',
#                '2014-12-31', '2014-11-28', '2014-10-31', '2014-09-30',
#                '2014-08-29', '2014-07-31', '2014-06-30', '2014-05-30',
#                '2014-04-30', '2014-03-31', '2014-02-28', '2014-01-30'],
#               dtype='datetime64[ns]', name='trade_date', freq=None)

# %%
#Product a well data framework
Data=pd.DataFrame([])
total_m=len(tradedate_m)
for i in range(total_m):
        
    stocks_wgt_m=BM_weight_real[BM_weight_real.index==tradedate_m[i]][['con_code','weight']]
    ##caculate the right weights(divide weights by their sum)
    stocks_wgt_m['weight']=stocks_wgt_m['weight']/sum(stocks_wgt_m['weight'])
    tdm=tradedate_m[i]
    ts_code=stocks_wgt_m['con_code']
    new_index=pd.DataFrame([])
    new_price=pd.DataFrame([])
    print(tdm)
    print('Datas of the {} constituent stocks for current month is going to be arranged'.format(len(ts_code)))
    if i == (total_m-1):
        for j in range(len(ts_code)):
            ##get the daily index datas of stocks forming the benchmark
            new_index_temp=stocks_index_d_real[
                    (stocks_index_d_real.index<=tradedate_m[i])&
                    (stocks_index_d_real.ts_code == ts_code.iloc[j])]
            new_index=pd.concat([new_index,new_index_temp],axis=0,sort=False)
            
            ##get the daily price datas of stocks forming the benchmark
            new_price_temp= stocks_price_d_real[
                    (stocks_price_d_real.index<=tradedate_m[i])&
                    (stocks_price_d_real.ts_code == ts_code.iloc[j])]
            new_price=pd.concat([new_price,new_price_temp],axis=0,sort=False)
        ##add the weight of the stocks in the benchmark
        #stocks_wgt_m['weight']=stocks_wgt_m['weight']/sum(stocks_wgt_m['weight'])
        new_price['weight']= np.linspace(1,len(new_price.ts_code),len(new_price.ts_code))
        for k in range(len(ts_code)):
            new_price.loc[new_price['ts_code']==stocks_wgt_m['con_code'].iloc[k],'weight']=stocks_wgt_m['weight'].iloc[k]
        ##merge index and stocks_price by columns
        Data_new=pd.concat([new_price,new_index],axis=1,sort=False)
        ##drop the duplicated columns(['Unnamed: 0','ts_code']).
        Data_new=Data_new.T.drop_duplicates().T
        Data=pd.concat([Data,Data_new],axis=0,sort=False)
        print('Arrangement well done for current month, {} months remain.'.format(len(tradedate_m)-i-1))    
    else:
        for j in range(len(ts_code)):
            ##get the daily index datas of stocks forming the benchmark
            new_index_temp=stocks_index_d_real[
                    (tradedate_m[i+1]<stocks_index_d_real.index)&
                    (stocks_index_d_real.index<=tradedate_m[i])&
                    (stocks_index_d_real.ts_code == ts_code.iloc[j])]
            new_index=pd.concat([new_index,new_index_temp],axis=0,sort=False)
            
            ##get the daily price datas of stocks forming the benchmark
            new_price_temp= stocks_price_d_real[
                    (tradedate_m[i+1]<stocks_price_d_real.index)&
                    (stocks_price_d_real.index<=tradedate_m[i])&
                    (stocks_price_d_real.ts_code == ts_code.iloc[j])]
            new_price=pd.concat([new_price,new_price_temp],axis=0,sort=False)
        ##add the weight of the stocks in the benchmark
        #stocks_wgt_m['weight']=stocks_wgt_m['weight']/sum(stocks_wgt_m['weight'])
        new_price['weight']= np.linspace(1,len(new_price.ts_code),len(new_price.ts_code))
        for k in range(len(ts_code)):
            new_price.loc[new_price['ts_code']==stocks_wgt_m['con_code'].iloc[k],'weight']=stocks_wgt_m['weight'].iloc[k]
        ##merge index and stocks_price by columns
        Data_new=pd.concat([new_price,new_index],axis=1,sort=False)
        ##drop the duplicated columns(['Unnamed: 0','ts_code']).
        Data_new=Data_new.T.drop_duplicates().T
        Data=pd.concat([Data,Data_new],axis=0,sort=False)
        
        ##Compute the number of missed constituent stocks
        if (len(ts_code)!=len(Data_new.loc[tdm,'weight'])):
            print('There are {} constituent stocks datas missed'
                  .format(len(ts_code)-len(Data_new.loc[tdm,'weight'])))
        print('Arrangement well done for current month, {} months remain.'.format(len(tradedate_m)-i-1))
# Out:
# 2019-05-31 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 63 months remain.
# 2019-04-30 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 62 months remain.
# 2019-03-29 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 61 months remain.
# 2019-02-28 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 60 months remain.
# 2019-01-31 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 59 months remain.
# 2018-12-28 00:00:00
# Datas of the 46 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 58 months remain.
# 2018-10-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 57 months remain.
# 2018-09-28 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 56 months remain.
# 2018-08-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 55 months remain.
# 2018-07-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 54 months remain.
# 2018-06-29 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 53 months remain.
# 2018-05-31 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 52 months remain.
# 2018-04-27 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 51 months remain.
# 2018-03-30 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 50 months remain.
# 2018-02-28 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 49 months remain.
# 2018-01-31 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 48 months remain.
# 2017-12-29 00:00:00
# Datas of the 53 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 47 months remain.
# 2017-11-30 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# There are 5 constituent stocks datas missed
# Arrangement well done for current month, 46 months remain.
# 2017-10-31 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 45 months remain.
# 2017-09-29 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 44 months remain.
# 2017-08-31 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 43 months remain.
# 2017-07-31 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 42 months remain.
# 2017-06-30 00:00:00
# Datas of the 56 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 41 months remain.
# 2017-05-31 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 40 months remain.
# 2017-04-28 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 39 months remain.
# 2017-03-31 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 38 months remain.
# 2017-02-28 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 37 months remain.
# 2017-01-26 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 36 months remain.
# 2016-12-30 00:00:00
# Datas of the 59 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 35 months remain.
# 2016-11-30 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 34 months remain.
# 2016-10-31 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 33 months remain.
# 2016-09-30 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 32 months remain.
# 2016-08-31 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 31 months remain.
# 2016-07-29 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 30 months remain.
# 2016-06-30 00:00:00
# Datas of the 47 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 29 months remain.
# 2016-05-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 28 months remain.
# 2016-04-29 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 27 months remain.
# 2016-03-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 26 months remain.
# 2016-02-29 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 25 months remain.
# 2016-01-29 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 24 months remain.
# 2015-12-31 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 23 months remain.
# 2015-11-30 00:00:00
# Datas of the 49 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 22 months remain.
# 2015-10-30 00:00:00
# Datas of the 49 constituent stocks for current month is going to be arranged
# There are 5 constituent stocks datas missed
# Arrangement well done for current month, 21 months remain.
# 2015-09-30 00:00:00
# Datas of the 49 constituent stocks for current month is going to be arranged
# There are 6 constituent stocks datas missed
# Arrangement well done for current month, 20 months remain.
# 2015-08-31 00:00:00
# Datas of the 49 constituent stocks for current month is going to be arranged
# There are 6 constituent stocks datas missed
# Arrangement well done for current month, 19 months remain.
# 2015-07-31 00:00:00
# Datas of the 49 constituent stocks for current month is going to be arranged
# There are 5 constituent stocks datas missed
# Arrangement well done for current month, 18 months remain.
# 2015-06-30 00:00:00
# Datas of the 50 constituent stocks for current month is going to be arranged
# There are 6 constituent stocks datas missed
# Arrangement well done for current month, 17 months remain.
# 2015-05-29 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 7 constituent stocks datas missed
# Arrangement well done for current month, 16 months remain.
# 2015-04-30 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 15 months remain.
# 2015-03-31 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 14 months remain.
# 2015-02-27 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 13 months remain.
# 2015-01-30 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 12 months remain.
# 2014-12-31 00:00:00
# Datas of the 40 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 11 months remain.
# 2014-11-28 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 10 months remain.
# 2014-10-31 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 9 months remain.
# 2014-09-30 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 8 months remain.
# 2014-08-29 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 7 months remain.
# 2014-07-31 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 2 constituent stocks datas missed
# Arrangement well done for current month, 6 months remain.
# 2014-06-30 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 1 constituent stocks datas missed
# Arrangement well done for current month, 5 months remain.
# 2014-05-30 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 4 months remain.
# 2014-04-30 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 3 constituent stocks datas missed
# Arrangement well done for current month, 3 months remain.
# 2014-03-31 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 2 months remain.
# 2014-02-28 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# There are 4 constituent stocks datas missed
# Arrangement well done for current month, 1 months remain.
# 2014-01-30 00:00:00
# Datas of the 35 constituent stocks for current month is going to be arranged
# Arrangement well done for current month, 0 months remain.

# %%
##Add benchmark close price to our well data-framework(Data)
Data['benchmark']=np.zeros(len(Data.index))
for i in range(len(tradedate_d)):
    tdd=tradedate_d[i]
    Data.loc[Data.index==tdd,'benchmark']=BM_price_real.loc[tdd,'close']

# %%
##Add the industry sector to our data

Data['code']=Data['ts_code'].apply(lambda x:x[:6]).tolist()
Data['sector']=np.zeros(len(df2['code']))
cc=list(df2['code'])
ds=ts.get_industry_classified()

for i in range(len(df2['code'])):
    print(i)
    sector=ds[ds.code.str.contains(cc[i])].c_name
    if len(sector)!=0:
        Data['sector'].iloc[i]=sector.iloc[0]
    else:
        Data['sector'].iloc[i]='NaN'
        print('no sector')    
    #df2.loc[df2['code']==,'sector']

# %%
Data_for_R=Data
Data_for_R.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\Data_for_R.csv',
                  sep=',', header=True, index=True)

# %%
print(Data.isnull().any())
# Out:
# Unnamed: 0           False
# ts_code              False
# open                 False
# high                 False
# low                  False
# close                False
# pre_close            False
# change               False
# pct_chg              False
# vol                  False
# amount               False
# MOM                   True
# APO                   True
# ROC                   True
# RSI                   True
# vol_volatility_1w     True
# vol_volatility_2w     True
# vol_volatility_1m     True
# OBV                  False
# volatility_1w         True
# volatility_2w         True
# volatility_1m         True
# weight               False
# turnover_rate        False
# volume_ratio          True
# pe                    True
# pb                   False
# ps                   False
# dv_ratio              True
# float_share          False
# free_share           False
# total_mv             False
# circ_mv              False
# benchmark            False
# dtype: bool

# %%
###Dealing with the NaN
Data=Data.fillna(method='bfill')
print(Data.isnull().any())
# Out:
# Unnamed: 0       False
# ts_code          False
# open             False
# high             False
# low              False
# close            False
# pre_close        False
# change           False
# pct_chg          False
# vol              False
# amount           False
# weight           False
# turnover_rate    False
# volume_ratio     False
# pe               False
# pb               False
# ps               False
# dv_ratio         False
# float_share      False
# free_share       False
# total_mv         False
# circ_mv          False
# benchmark        False
# dtype: bool

# %%
Data.to_csv('F:\\Courses\\HKUST_Semester_Spring\\MAFS5210\\project1\\Data.csv', sep=',', header=True, index=True)

# %%
Data.columns
# Out:
# Index(['Unnamed: 0', 'ts_code', 'open', 'high', 'low', 'close', 'pre_close',
#        'change', 'pct_chg', 'vol', 'amount', 'weight', 'turnover_rate',
#        'volume_ratio', 'pe', 'pb', 'ps', 'dv_ratio', 'float_share',
#        'free_share', 'total_mv', 'circ_mv'],
#       dtype='object')

# %%
Data.index
# Out:
# DatetimeIndex(['2019-05-31', '2019-05-30', '2019-05-29', '2019-05-28',
#                '2019-05-27', '2019-05-24', '2019-05-23', '2019-05-22',
#                '2019-05-21', '2019-05-20',
#                ...
#                '2014-01-15', '2014-01-14', '2014-01-13', '2014-01-10',
#                '2014-01-09', '2014-01-08', '2014-01-07', '2014-01-06',
#                '2014-01-03', '2014-01-02'],
#               dtype='datetime64[ns]', name='trade_date', length=59356, freq=None)

# %%
print(Data.describe())
# Out:
#          Unnamed: 0          open          high           low         close  \
# count  59356.000000  59356.000000  59356.000000  59356.000000  59356.000000
# mean     732.007733     22.814818     23.272334     22.388358     22.839605
# std      341.766142     20.779914     21.277476     20.326010     20.819948
# min      139.000000      2.510000      2.720000      2.460000      2.560000
# 25%      448.000000     11.370000     11.570000     11.180000     11.380000
# 50%      714.000000     17.500000     17.790000     17.210000     17.500000
# 75%     1003.000000     26.770000     27.280000     26.260000     26.800000
# max     1462.000000    251.000000    257.790000    249.480000    255.300000
#
#           pre_close        change       pct_chg           vol        amount  \
# count  59356.000000  59356.000000  59356.000000  5.935600e+04  5.935600e+04
# mean      22.835627      0.003978      0.032527  1.038869e+05  1.838608e+05
# std       20.804639      0.980779      2.816942  1.387464e+05  2.260253e+05
# min        2.560000    -23.800000    -10.115600  3.970000e+02  1.564762e+03
# 25%       11.380000     -0.200000     -1.200000  3.529237e+04  6.090159e+04
# 50%       17.510000      0.000000      0.000000  6.493976e+04  1.119174e+05
# 75%       26.790000      0.210000      1.260000  1.217193e+05  2.153057e+05
# max      255.300000     20.700000     10.137000  4.063436e+06  4.990416e+06
#
#        ...  volume_ratio            pe            pb            ps  \
# count  ...  59356.000000  59356.000000  59356.000000  59356.000000
# mean   ...      1.055931     83.146156      4.785453      7.099529
# std    ...      0.742976    202.108803      3.717489      8.308290
# min    ...      0.000000      3.818800      0.788000      0.275000
# 25%    ...      0.720000     27.724850      2.596100      2.358550
# 50%    ...      0.920000     39.549700      3.725400      4.542050
# 75%    ...      1.220000     64.132975      5.642325      8.871600
# max    ...     99.130000   4247.038100     55.446000    108.246000
#
#            dv_ratio    float_share     free_share      total_mv       circ_mv  \
# count  59356.000000   59356.000000   59356.000000  5.935600e+04  5.935600e+04
# mean       0.904348   72106.386330   44806.602855  1.482716e+06  1.185892e+06
# std        1.170567   49201.725107   30137.829640  7.172061e+05  6.352528e+05
# min        0.020000    4200.000000    3849.810100  3.160738e+05  1.476299e+05
# 25%        0.360000   39000.000000   24144.473100  9.172168e+05  7.245134e+05
# 50%        0.680000   57169.594800   38303.128800  1.359258e+06  1.003571e+06
# 75%        1.140000   94659.972500   55622.796200  1.908901e+06  1.517354e+06
# max       15.040000  266057.834700  171865.085100  5.657301e+06  4.802925e+06
#
#           benchmark
# count  59356.000000
# mean   11832.924212
# std     2150.762386
# min        0.000000
# 25%    10474.873100
# 50%    11870.065700
# 75%    12739.914900
# max    21950.297700
#
# [8 rows x 22 columns]

# %%
np.where(Data.benchmark==0)
# Out:
# (array([57535, 57556, 57577, 57598, 57619, 57640, 57661, 57682, 57703,
#         57724, 57745, 57766, 57787, 57808, 57829, 57850, 57871, 57892,
#         57913, 57934, 57955, 57976, 57997, 58018, 58039, 58060, 58081,
#         58102, 58123, 58144, 58165], dtype=int64),)

# %%
# Out:
# (array([], dtype=int64),)
